# %%
import numpy as np
import ctqmc
import importlib
import conf
import ctqmc
import mpl_interface
import collections
from mpl_interface import plt, spinplot, bondplot, cutplot
importlib.reload(conf)
importlib.reload(ctqmc)
importlib.reload(mpl_interface)
# Out:
# <module 'mpl_interface' from '/root/study/ctqmc/mpl_interface.py'>

# %%
p = {'beta': 10, 'J': 1.0, 'Hx': 1.0,'L': 2}
u = ctqmc.Updater(**p)

# %%
fig, ax = plt.subplots()
ax.spinplot(u.cuttaux)
ax.cutplot(u.cuttaux)

# %%
u.add_cut()

# %%
ax.cutplot(u.cuttaux)
fig

# %%
u.update_bond()
ax.bondplot(u.bond)
fig

# %%
u.update()
fig2, ax2 = plt.subplots()
ax2.spinplot(u.cuttaux)
ax2.cutplot(u.cuttaux)
ax2.bondplot(u.bond)
